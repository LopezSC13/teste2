# %% [markdown]
# <a href="https://colab.research.google.com/github/LopezSC13/teste2/blob/main/a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dados = pd.read_excel("https://github.com/LopezSC13/teste2/raw/main/bases_procvv.xlsx")
dados
# Out:
#     reg-a                       CENTRO  reg-n
# 0   DRCAP              CASA BELA VISTA  DRCAP
# 1   DRCAP  CASA GOVERNADOR MÁRIO COVAS  DRCAP
# 2   DRCAP            CASA JOÃO DO PULO  DRCAP
# 3   DRCAP               CASA NOVA VIDA  DRCAP
# 4   DRCAP                    CASA ÔNIX  DRCAP
# ..    ...                          ...    ...
# 91   DRVP     CASA SERRA DA CANTAREIRA  DRCAP
# 92   DRVP    CASA SERRA DA MANTIQUEIRA    DR3
# 93   DRVP                 CASA TAMOIOS    DR3
# 94   DRVP                 CASA TAUBATE    DR3
# 95   DRVP              CASA TERRA NOVA  DRCAP
#
# [96 rows x 3 columns]

# %%
dados.shape
# Out:
# (96, 3)

# %%
dados.columns = ["ANTIGA","CENTRO","REGIONAL"]
dados
# Out:
#    ANTIGA                       CENTRO REGIONAL
# 0   DRCAP              CASA BELA VISTA    DRCAP
# 1   DRCAP  CASA GOVERNADOR MÁRIO COVAS    DRCAP
# 2   DRCAP            CASA JOÃO DO PULO    DRCAP
# 3   DRCAP               CASA NOVA VIDA    DRCAP
# 4   DRCAP                    CASA ÔNIX    DRCAP
# ..    ...                          ...      ...
# 91   DRVP     CASA SERRA DA CANTAREIRA    DRCAP
# 92   DRVP    CASA SERRA DA MANTIQUEIRA      DR3
# 93   DRVP                 CASA TAMOIOS      DR3
# 94   DRVP                 CASA TAUBATE      DR3
# 95   DRVP              CASA TERRA NOVA    DRCAP
#
# [96 rows x 3 columns]

# %%
dados.head()
# Out:
#   ANTIGA                       CENTRO REGIONAL
# 0  DRCAP              CASA BELA VISTA    DRCAP
# 1  DRCAP  CASA GOVERNADOR MÁRIO COVAS    DRCAP
# 2  DRCAP            CASA JOÃO DO PULO    DRCAP
# 3  DRCAP               CASA NOVA VIDA    DRCAP
# 4  DRCAP                    CASA ÔNIX    DRCAP

# %%
df = pd.DataFrame(dados)


nome_desejado = input ("Digite a Regional desejada: ")

# Cria a máscara booleana
mascara = df['REGIONAL'] == nome_desejado

# Seleciona as linhas correspondentes à máscara
linhas_selecionadas = df[mascara]

# Imprime o resultado
print(linhas_selecionadas)

# Conta o número de linhas selecionadas
contagem_linhas_selecionadas = linhas_selecionadas.shape[0]

# Imprime a contagem
print(f"A {nome_desejado}  possui : {contagem_linhas_selecionadas} centros")
# Out:
# Digite a Regional desejada: DR3
#    ANTIGA                                     CENTRO REGIONAL
# 40   DRMC                             CAIP JACARANDÁ      DR3
# 41   DRMC                            CAIP ANDORINHAS      DR3
# 42   DRMC                              CASA CAMPINAS      DR3
# 43   DRMC              CASA DE SEMILIBERDADE JUNDIAÍ      DR3
# 44   DRMC                           CASA LARANJEIRAS      DR3
# 45   DRMC                               CASA LIMEIRA      DR3
# 46   DRMC                  CASA MAESTRO CARLOS GOMES      DR3
# 47   DRMC                       CASA MANACÁ DA SERRA      DR3
# 48   DRMC                            CASA MOGI MIRIM      DR3
# 49   DRMC                            CASA MORRO AZUL      DR3
# 50   DRMC                            CASA NOVO TEMPO      DR3
# 51   DRMC                        CASA RIO PIRACICABA      DR3
# 52   DRMC                               CASA TAPAJÓS      DR3
# 83   DRVP                               CASA ATIBAIA      DR3
# ...
